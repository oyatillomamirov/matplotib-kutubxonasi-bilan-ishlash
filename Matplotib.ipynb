# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([3,5,7,3])
y1=np.array([4,8,4,4])
x2=np.array([3.5,3.5,6.5,6.5,3.5])
y2=np.array([-2,4,4,-2,-2])
x3 = np.array([4.7, 4.7, 5.3, 5.3, 4.7])
y3 = np.array([4.2, 6,   6,   4.2, 4.2])
x4=np.array([3.7,3.7,4.3,4.3,3.7,4,4,4,3.9,4.1])
y4=np.array([0,-2,-2,0,0,0,-2,-1.3,-1.3,-1.3])
x5=np.array([5.6,5.6,6,6])
y5=np.array([6.8,8.3,8.3,6])
plt.plot(x1,y1,x2,y2,x3,y3,x4,y4,x5,y5)
plt.fill(x1, y1, color='black', alpha=2)
plt.fill(x3,y3,  color='yellow')
plt.fill(x5,y5,  color='grey')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1515286274.py in <cell line: 0>()
#      12 y5=np.array([6.8,8.3,8.3,6])
#      13 plt.plot(x1,y1,x2,y2,x3,y3,x4,y4,x5,y5)
# ---> 14 plt.fill(x1, y1, color='black', alpha=2)
#      15 plt.fill(x3,y3,  color='yellow')
#      16 plt.fill(x5,y5,  color='grey')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in fill(data, *args, **kwargs)
#    3324 @_copy_docstring_and_deprecators(Axes.fill)
#    3325 def fill(*args, data=None, **kwargs) -> list[Polygon]:
# -> 3326     return gca().fill(*args, **({"data": data} if data is not None else {}), **kwargs)
#    3327
#    3328
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in fill(self, data, *args, **kwargs)
#    5564         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([3,5,7,3])
y1=np.array([4,8,4,4])
x2=np.array([3.5,3.5,6.5,6.5,3.5])
y2=np.array([-2,4,4,-2,-2])
x3=np.array([4.7,4.7,5.3,5.3,4.7,5,5])
y3=np.array([4.2,6,6,4.2,4.2,4.2,6])
x4=np.array([3.7,3.7,4.3,4.3,3.7,4,4,4,3.9,4.1])
y4=np.array([0,-2,-2,0,0,0,-2,-1.3,-1.3,-1.3])
x5=np.array([5.6,5.6,6,6])
y5=np.array([6.8,8.3,8.3,6])
plt.plot(x1,y1,x2,y2,x3,y3,x4,y4,x5,y5)
plt.fill(x1, y1, color='gray', alpha=1)
plt.fill(x3,y3,  color='white', alpha=1)
plt.fill(x4,y4, color='blue')
plt.fill(x2,y2, color='beige')
plt.fill(x5,y5, color='darkgray')
plt.plot(x1, y1, color="gray")
plt.plot(x2, y2, color="beige")
plt.plot(x3, y3, color="black")
plt.plot(x4, y4, color="black")
plt.plot(x5, y5, color="darkgray")


plt.show()
